# %%
import string

import pandas as pd
import numpy as np

import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\basit\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
datasets=pd.read_csv("C://Users//basit//Downloads/spam_ham_dataset.csv")
datasets.head(3)
# Out:
#    Unnamed: 0 label                                               text  label_num
# 0         605   ham  Subject: enron methanol ; meter # : 988291\r\n...          0
# 1        2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...          0
# 2        3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...          0

# %%
datasets.shape
# Out:
# (5171, 4)

# %%
datasets['text'] = datasets['text'].apply(lambda x: x.replace('\r\n',''))

# %%
da

# %%
datasets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5171 entries, 0 to 5170
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5171 non-null   int64
#  1   label       5171 non-null   object
#  2   text        5171 non-null   object
#  3   label_num   5171 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 161.7+ KB

# %%
datasets.isnull().sum()
# Out:
# Unnamed: 0    0
# label         0
# text          0
# label_num     0
# dtype: int64

# %%
stemmer = PorterStemmer()
corpus = []

# Define stopwords
stopwords_set = set(stopwords.words('english'))

for i in range(len(datasets)):
    # Convert to lowercase
    text = datasets['text'].iloc[i].lower()
    
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    
    # Tokenize and process text
    text = text.split()
    text = [stemmer.stem(word) for word in text if word not in stopwords_set]
    
    # Join back into a single string
    text = ' '.join(text)
    
    # Append to the corpus
    corpus.append(text)

# %%
cv = CountVectorizer()
x = cv.fit_transform(corpus).toarray()
y = datasets.label_num

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
rf = RandomForestClassifier(n_jobs=-1) 
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_jobs=-1)

# %%
rf.score(x_test,y_test)
# Out:
# 0.9632850241545894

# %%
rf.score(x_train,y_train)
# Out:
# 1.0

# %%
email_to_classify = datasets.text.values[15]

# %%
email_to_classify
# Out:
# "Subject: underpriced issue with high return on equitystock report .dont sieep on this stock ! this is a hot one !company : gaming transactions inc .stock symbol : ggtscurrentiy trading at : o . 30rating : strong purchasenear - term target : 0 . 45long - term target : 1 . oobreaking news for ggts :gaming transactions inc . ( ggts ) , a | eading provider of online gamingporta | management is pleased to announce that it has launched itsproprietary gaming portal ( k e n o . com ) furthermore , the company has begun anintensive marketing campaign to support the | aunch and establish itselfas the | eader in the online gaming industry .( k e n o . c o m ) is an oniine games destination where people piaypopular casino style games to win real money . the foundation of the site isan online version of keno . the game of keno uses 80 balls numbered 1thru 8 o . every game , the house draws 20 bails at random and displaystheir numbers on screens ( called keno boards ) located on the website . the
# ...

# %%
email_text = email_to_classify.lower().translate(str.maketrans('', '', string.punctuation)).split()
email_text = [stemmer.stem(word) for word in email_text if word not in stopwords_set]
email_text = ''.join(email_text)

email_corpus = [email_text]

x_mail = cv.transform(email_corpus)

# %%
rf.predict(x_mail)
# Out:
# array([1])

# %%
datasets.label_num.iloc[15]
# Out:
# np.int64(1)
